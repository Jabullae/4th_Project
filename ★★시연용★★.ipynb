# %%
from IPython.display import Image, display

# %% [markdown]
# # 사진

# %% [markdown]
# ## sample1

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp8/weights/best.pt --img 640 --conf 0.2 --source upload/바다쓰레기.jpg
# Out:
# 'cp949' codec can't decode byte 0xf0 in position 9: illegal multibyte sequence
# detect: weights=['yolov5/runs/train/exp8/weights/best.pt'], source=upload/.jpg, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-42-g5545ff3 Python-3.9.7 torch-1.9.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7034398 parameters, 0 gradients
# image 1/1 C:\dev\MLDL\mini\upload\.jpg: 480x640 10 plastics, 214.5ms
# Speed: 2.0ms pre-process, 214.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5\runs\detect\exp17

# %%
Image('yolov5/runs/detect/exp17/바다쓰레기.jpg')

# %% [markdown]
# ## sample2

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp8/weights/best.pt --img 640 --conf 0.25 --source upload/영현이책상.jpg
# Out:
# 'cp949' codec can't decode byte 0xf0 in position 9: illegal multibyte sequence
# detect: weights=['yolov5/runs/train/exp8/weights/best.pt'], source=upload/.jpg, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-42-g5545ff3 Python-3.9.7 torch-1.9.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7034398 parameters, 0 gradients
# image 1/1 C:\dev\MLDL\mini\upload\.jpg: 480x640 1 trash, 1 plastic, 1 metal, 1 glass, 6 papers, 2 vinyls, 225.4ms
# Speed: 2.0ms pre-process, 225.4ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5\runs\detect\exp20

# %%
Image('yolov5/runs/detect/exp20/영현이책상.jpg')

# %% [markdown]
# # 영상

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp8/weights/best.pt --img 640 --conf 0.25 --source upload/우리반쓰레기통.mp4
# Out:
# 'cp949' codec can't decode byte 0xf0 in position 9: illegal multibyte sequence
# detect: weights=['yolov5/runs/train/exp8/weights/best.pt'], source=upload/.mp4, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-42-g5545ff3 Python-3.9.7 torch-1.9.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7034398 parameters, 0 gradients
# video 1/1 (1/231) C:\dev\MLDL\mini\upload\.mp4: 640x384 2 plastics, 162.6ms
# video 1/1 (2/231) C:\dev\MLDL\mini\upload\.mp4: 640x384 1 plastic, 170.5ms
# video 1/1 (3/231) C:\dev\MLDL\mini\upload\.mp4: 640x384 1 plastic, 157.6ms
# ...

# %% [markdown]
# # Youtube

# %%
! pip install pytube
# Out:
# ...
# WARNING: Ignoring invalid distribution -orch (c:\ananconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\ananconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\ananconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\ananconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\ananconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\ananconda3\lib\site-packages)

# %%
#비디오 다운로드(해상도 가장 좋은 것으로 필터)
import pytube
yt = pytube.YouTube("https://www.youtube.com/watch?v=GvJTK_s7mPk")
file_name = yt.title
yt.streams.filter(adaptive=True, file_extension='mp4', only_video=True).order_by('resolution').desc().first().download('upload', 'sample.mp4')
# Out:
# 'c:\\dev\\MLDL\\mini\\upload\\sample.mp4'

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp8/weights/best.pt --img 640 --conf 0.2 --source upload/sample.mp4
# Out:
# 'cp949' codec can't decode byte 0xf0 in position 9: illegal multibyte sequence
# detect: weights=['yolov5/runs/train/exp8/weights/best.pt'], source=upload/sample.mp4, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-42-g5545ff3 Python-3.9.7 torch-1.9.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7034398 parameters, 0 gradients
# video 1/1 (1/2598) C:\dev\MLDL\mini\upload\sample.mp4: 384x640 4 plastics, 1 paper, 1 vinyl, 182.5ms
# video 1/1 (2/2598) C:\dev\MLDL\mini\upload\sample.mp4: 384x640 5 plastics, 1 paper, 1 vinyl, 166.5ms
# ...
